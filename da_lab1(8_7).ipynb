# %% [markdown]
# <a href="https://colab.research.google.com/github/Nirtika123/product-dataset-eda/blob/main/da_lab1(8_7).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('lab1dataset.csv')

# %% [markdown]
# 1. How many product records are available in the dataset?

# %%
pd.read_csv("lab1dataset.csv")
# Out:
#      Category   Price    Rating         Stock  Discount
# 0         NaN  5548.0  1.870322           NaN       0.0
# 1         NaN  3045.0  4.757798           NaN      38.0
# 2         NaN  4004.0       NaN      In Stock       0.0
# 3         NaN  4808.0  1.492085           NaN      33.0
# 4         NaN  1817.0       NaN  Out of Stock      23.0
# ...       ...     ...       ...           ...       ...
# 4357      NaN  4436.0  4.728335           NaN      49.0
# 4358        B  6236.0       NaN  Out of Stock       4.0
# 4359      NaN  3283.0       NaN  Out of Stock       9.0
# 4360        D  2999.0  4.425995           NaN      40.0
# 4361      NaN     NaN  2.184471           NaN       0.0
#
# [4362 rows x 5 columns]

# %% [markdown]
# 2. How many columns are available in the dataset?

# %%
df.shape[1]
# Out:
# 5

# %% [markdown]
# 3. What product-related details are captured in the dataset?

# %%
df.columns.tolist()
# Out:
# ['Category', 'Price', 'Rating', 'Stock', 'Discount']

# %% [markdown]
# 4.What are the first five product records in the dataset?

# %%
df.head()
# Out:
#   Category   Price    Rating         Stock  Discount
# 0      NaN  5548.0  1.870322           NaN       0.0
# 1      NaN  3045.0  4.757798           NaN      38.0
# 2      NaN  4004.0       NaN      In Stock       0.0
# 3      NaN  4808.0  1.492085           NaN      33.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0

# %% [markdown]
# 5. What are the last five product records in the dataset?

# %%
df.tail()
# Out:
#      Category   Price    Rating         Stock  Discount
# 4357      NaN  4436.0  4.728335           NaN      49.0
# 4358        B  6236.0       NaN  Out of Stock       4.0
# 4359      NaN  3283.0       NaN  Out of Stock       9.0
# 4360        D  2999.0  4.425995           NaN      40.0
# 4361      NaN     NaN  2.184471           NaN       0.0

# %% [markdown]
# 6. What type of data is stored in each column?

# %%
df.dtypes
# Out:
# Category     object
# Price       float64
# Rating      float64
# Stock        object
# Discount    float64
# dtype: object

# %% [markdown]
# 7. Which columns can be used for numerical analysis?

# %%
df.select_dtypes(include="number").columns.tolist()
# Out:
# ['Price', 'Rating', 'Discount']

# %% [markdown]
# 8. Which columns can be used for category-wise analysis?

# %%
df.select_dtypes(include="object").columns.tolist()
# Out:
# ['Category', 'Stock']

# %% [markdown]
# 9. How many total data values are present in the dataset?

# %%
df.size
# Out:
# 21810

# %% [markdown]
# 10. What is the non-null count for each column?

# %%
df.notnull().sum()
# Out:
# Category    1614
# Price       4188
# Rating      2312
# Stock       3010
# Discount    3970
# dtype: int64

# %% [markdown]
# 11. How many missing values are present in each column?

# %%
df.isnull().sum()
# Out:
# Category    2748
# Price        174
# Rating      2050
# Stock       1352
# Discount     392
# dtype: int64

# %% [markdown]
# 12. What is the total number of missing values in the dataset?

# %%
df.isnull().sum().sum()
# Out:
# np.int64(6716)

# %% [markdown]
# 13. Which column has the highest number of missing values?

# %%
df.isnull().sum().idxmax()
# Out:
# 'Category'

# %% [markdown]
# 14. Which column has the lowest number of missing values?

# %%
df.isnull().sum().idxmin()
# Out:
# 'Price'

# %% [markdown]
# 15. What percentage of values are missing in each column?

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# Category    62.998624
# Price        3.988996
# Rating      46.996790
# Stock       30.994956
# Discount     8.986703
# dtype: float64

# %% [markdown]
# 16. Which columns need attention because of missing values?

# %%
df.columns[df.isnull().sum() > 0]
# Out:
# Index(['Category', 'Price', 'Rating', 'Stock', 'Discount'], dtype='object')

# %% [markdown]
# 17. How many duplicate product records are present in the dataset?

# %%
df.duplicated().sum()
# Out:
# np.int64(15)

# %% [markdown]
# 18. What are the duplicate records found in the dataset?

# %%
df[df.duplicated()]
# Out:
#      Category  Price  Rating         Stock  Discount
# 505       NaN    NaN     NaN           NaN       NaN
# 1746      NaN    NaN     NaN      In Stock      44.0
# 1760      NaN    NaN     NaN      In Stock      44.0
# 2051      NaN    NaN     NaN           NaN       NaN
# 2124      NaN    NaN     NaN  Out of Stock       NaN
# 2241      NaN    NaN     NaN  Out of Stock       NaN
# 3302      NaN    NaN     NaN      In Stock       1.0
# 3314      NaN    NaN     NaN  Out of Stock      16.0
# 3527      NaN    NaN     NaN  Out of Stock      26.0
# 3553      NaN    NaN     NaN  Out of Stock      28.0
# 3918      NaN    NaN     NaN           NaN      42.0
# 3957      NaN    NaN     NaN  Out of Stock       NaN
# 4001      NaN    NaN     NaN      In Stock       1.0
# 4344      NaN    NaN     NaN           NaN       0.0
# 4355      NaN    NaN     NaN      In Stock      46.0

# %% [markdown]
# 19. Is the dataset free from duplicate records?

# %%
df.duplicated().sum() == 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1859/1717174882.py in <cell line: 0>()
# ----> 1 df.duplicated().sum() == 0
#
# NameError: name 'df' is not defined

# %% [markdown]
# 20. What is the lowest product price in the dataset?

# %%
df["Price"].min()
# Out:
# 102.0

# %% [markdown]
# 21. What is the highest product price in the dataset?

# %%
df["Price"].max()
# Out:
# 9999.0

# %% [markdown]
# 22. What is the average product price?

# %%
df["Price"].mean()
# Out:
# np.float64(5016.970630372492)

# %% [markdown]
# 23. What is the complete statistical summary of product price?

# %%
df["Price"].describe()
# Out:
# count    4188.000000
# mean     5016.970630
# std      2839.984813
# min       102.000000
# 25%      2628.250000
# 50%      4996.500000
# 75%      7418.000000
# max      9999.000000
# Name: Price, dtype: float64

# %% [markdown]
# 24. What is the lowest customer rating in the dataset?

# %%
df["Rating"].min()
# Out:
# 1.0003662024741131

# %% [markdown]
# 25. What is the highest customer rating in the dataset?

# %%
df["Rating"].max()
# Out:
# 4.997817693458396

# %% [markdown]
# 26. What is the average customer rating?

# %%
df["Rating"].mean()
# Out:
# np.float64(3.0382925191086185)

# %% [markdown]
# 27. What is the highest discount offered on a product?

# %%
df["Discount"].max()
# Out:
# 49.0

# %% [markdown]
# 28. What is the average discount offered on products?

# %%
df["Discount"].mean()
# Out:
# np.float64(24.516624685138538)

# %% [markdown]
# 29. How many unique product categories are available in the dataset?

# %%
df["Category"].nunique()
# Out:
# 4

# %% [markdown]
# 30. Which stock status occurs most frequently in the dataset?

# %%
df["Stock"].value_counts().idxmax()
# Out:
# 'In Stock'
